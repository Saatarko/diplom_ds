# %%
import numpy as np
import random
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from gymnasium import ObservationWrapper
from gymnasium.spaces import Box
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
import csv
import uuid

# %% [markdown]
# 1. Элементы лабиринта
# - Стены
# - Путь к выходу
# - Ключ и дверь (выход доступен только с ключом)
# - Ловушки, которые уменьшают здоровье
# - Костёр восстановления здоровья
#
# 2. Структура лабиринта
# Каждая клетка в лабиринте будет иметь код:
# - 0: Пустая клетка
# - 1: Стена
# - 2: Ключ
# - 3: Дверь
# - 4: Ловушка
# - 5: Костёр
# - 6: Игрок
# - 7: Выход

# %%
# Размеры лабиринта
WIDTH =50
HEIGHT = 50

EMPTY = 0
WALL = 1
KEY = 2
DOOR = 3
TRAP = 4
CAMPFIRE = 5
EXIT = 7

# %%
# Создание пустой карты
def create_empty_maze(width, height):
    return np.ones((height, width), dtype=int)  # Всё это стены (1)

# Генерация случайного пути (Алгоритм DFS)
def generate_path(maze, start, end):
    stack = [start]
    visited = set()
    while stack:
        current = stack[-1]
        if current == end:
            break
        visited.add(current)
        x, y = current
        neighbors = []
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx < maze.shape[0] and 0 <= ny < maze.shape[1] and maze[nx, ny] == 1 and (nx, ny) not in visited:
                neighbors.append((nx, ny))
        if neighbors:
            next_cell = random.choice(neighbors)
            maze[next_cell] = 0
            stack.append(next_cell)
        else:
            stack.pop()

# Размещение ключа и двери
def place_key_and_door(maze, start, end):
    key_pos = random.choice([(x, y) for x in range(maze.shape[0]) for y in range(maze.shape[1]) if maze[x, y] == 0])
    door_pos = random.choice([(x, y) for x in range(maze.shape[0]) for y in range(maze.shape[1]) if maze[x, y] == 0 and (x, y) != key_pos])
    
    maze[key_pos] = 2  # Ключ
    maze[door_pos] = 3  # Дверь

# Размещение ловушек и костров
def place_traps_and_campfires(maze):
    num_traps = random.randint(3, 5)
    num_campfires = random.randint(2, 4)

    for _ in range(num_traps):
        trap_pos = random.choice([(x, y) for x in range(maze.shape[0]) for y in range(maze.shape[1]) if maze[x, y] == 0])
        maze[trap_pos] = 4  # Ловушка

    for _ in range(num_campfires):
        campfire_pos = random.choice([(x, y) for x in range(maze.shape[0]) for y in range(maze.shape[1]) if maze[x, y] == 0])
        maze[campfire_pos] = 5  # Костёр

# %%
def generate_maze(
    width=15,
    height=15,
    start_pos=(1, 1),
    num_traps=4,
    num_campfires=3,
    algo='dfs'  # пока только dfs, но задел под выбор
):
    if width % 2 == 0: width += 1
    if height % 2 == 0: height += 1

    maze = np.ones((height, width), dtype=int)  # Стены

    def carve_dfs(x, y):
        dirs = [(2,0), (-2,0), (0,2), (0,-2)]
        random.shuffle(dirs)
        for dx, dy in dirs:
            nx, ny = x + dx, y + dy
            if 1 <= nx < height-1 and 1 <= ny < width-1 and maze[nx, ny] == WALL:
                maze[nx, ny] = EMPTY
                maze[x + dx//2, y + dy//2] = EMPTY
                carve_dfs(nx, ny)

    # Выбор алгоритма генерации
    if algo == 'dfs':
        x, y = start_pos
        maze[x, y] = EMPTY
        carve_dfs(x, y)
    else:
        raise NotImplementedError(f"Алгоритм '{algo}' ещё не реализован")

    # Добавим полезную функцию выбора случайной пустой клетки
    def place_tile(tile_code, count=1):
        placed = 0
        while placed < count:
            x, y = random.randint(1, height-2), random.randint(1, width-2)
            if maze[x, y] == EMPTY:
                maze[x, y] = tile_code
                placed += 1

    place_tile(KEY, 1)
    place_tile(DOOR, 1)
    place_tile(TRAP, num_traps)
    place_tile(CAMPFIRE, num_campfires)

    # Выход
    while True:
        x, y = random.randint(1, height-2), random.randint(1, width-2)
        if maze[x, y] == EMPTY:
            maze[x, y] = EXIT
            break

    return maze

# %%
def print_maze(maze, start_pos=None):
    symbols = {
        EMPTY: ' ', WALL: '█', KEY: 'K', DOOR: 'D',
        TRAP: 'T', CAMPFIRE: 'C', EXIT: 'E'
    }

    for i, row in enumerate(maze):
        line = ""
        for j, cell in enumerate(row):
            if start_pos is not None and (i, j) == start_pos:
                line += 'S'
            else:
                line += symbols.get(cell, '?')
        print(line)

# %%
def save_maze(maze, path="maze.csv"):
    np.savetxt(path, maze, fmt='%d', delimiter=",")


def save_episode_log(log, path="episode_log.csv"):
    with open(path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["step", "x", "y", "action", "tile", "reward", "health", "has_key"])
        writer.writerows(log)

# %%
# Генерируем и печатаем лабиринт
maze = generate_maze(
    width=50,
    height=50,
    start_pos=(1, 1),
    num_traps=6,
    num_campfires=2
)
print_maze(maze, start_pos=(1, 1))
# Out:
# ███████████████████████████████████████████████████
# █S█   █                 █           █   █       █ █
# █ █ █ █ █ ███████████████ █████ ███ █ █ █████ █ █ █
# █ █ █   █     █     █   C █   █ █ █   █       █   █
# █ █ █████████ █ ███ █ █████ █ █ █ ███████████████ █
# █ █     █ █   █ █ █   █     █ █ █       █         █
# █ █████ █ █ ███ █ █████████ █ █ █ █ █████ █████████
# █   █ █   █   █     █       █ █ █ █ █     █       █
# ███ █ ███ ███ █████ ███ █████ █ █ ███ █████ ███ █ █
# █   █     █ █     █     █ █   █ █     █   █   █ █ █
# █ █████ ███ █████ ███████ █ ███ █ █████ █ █████ █ █
# █     █       █ █     █ █   █   █ █     █ █   █ █ █
# █████ ███████ █ ███ █ █ █ ███ ███ █ █████ █ █ █ █ █
# █     █     █   █ █ █ D █ █ █ █ █   █   █   █   █ █
# █ █████ ███████ █ █ █ ███ █ █ █ ███████ █████████ █
# █ █   █ █       █ █ █ █     █ █         █       █ █
# █ █ █ █ █ ███████ █ ███ █████ █ ███ ███ █ █ ███ █ █
# █   █ █   █   █   █     █     █ █   █   █ █   █ █ █
# █████ █ ███ █ █ █ ███████ ███████ ███ ███ ███ █ █ █
# █   █ █ █   █   █   █ █   █       █   █   █ █ █ █ █
# █ ███ █ ███ █████ █ █T█ █████ █████ ███ ███ █ █ █ █
# █ █   █   █     █ █ █ █ █   █     █ █   █   █ █ █ █
# █ █ █████ ███████ █ █ █ █ █ █ ███ ███ █████ █ ███ █
# █ █   █ █   █   █ █   █   █ █   █   █ █     █   █ █
# █ ███ █ ███ █ █ █ ███ █████ ███ ███ █ █ █ █ ███ █ █
# █   █ █   █   █   █   █   █   █ █ █   █ █ █   █   █
# ███ █ █ ███████ ███████ █ █ █ █ █ █████ █ █████████
# █   █ █ █       █   █   █ █ █ █ █    T█ █         █
# █ ███ █ █ ███████ █ █ ███ ███ █ █ ███ █ █████ ███ █
# █ █   █ █       █ █   █ █   █ █   █ █ █ █     █ █ █
# █ █ ███ █ █████ █ █████ ███ █ █████ █ █ █ █████ █ █
# █ █   █   █   █ █ █       █ █ █ T   █ █ █   █   █ █
# █ ███ █ ███ █ █ █ █████ █ █ █ █ ███ █ ███ █ █ ███ █
# █ █   █ █   █ █ █     █ █     █ █   █   █ █ █     █
# █ █ █████ ███ █ █████ █████████ █ █████ ███ █ █████
# █ █ █     █ █ █   █ █ █   █     █     █   █ █     █
# █ █ ███ ███ █ ███ █ █ █ █ █ ███████ █████ █K███████
# █ █   █ █ T █ █     █   █ █       █ █     █       █
# █ ███ █ ███ █ █████████ █ ███ █████ █ █████ █████ █
# █   █ █   █       █   █ █   █ █     █ █       █   █
# ███ █ ███ ███████ █ █ ███ █ █ █ █████ ███ █████ █ █
# █   █   █   █     █ █ T █ █ █ █ █   █   █ █   █ █ █
# █ █████ █ █ █ █████C███ ███ █ █ █ █ ███ ███ █ █ █ █
# █ █     █ █ █       █ █     █ █   █   █     █ █ █ █
# █ █ ███████ █████████ ███████ ███████ ███████ █ █ █
# █   █   █   █ █       █     █   █ █   █   █   █ █ █
# █ ███ █ █ ███ █ ███ █ █ ███ ███ █ █ █ █ █E█ ███ █ █
# █     █ █ █   █ █ █ █ █ █   █   █ █ █   █ █     █ █
# ███████ █ █ ███ █ █ ███ █ ███ ███ █ █████████████ █
# █       T █       █     █         █               █
# ███████████████████████████████████████████████████

# %%
class MazeEnv(gym.Env):
    def __init__(self, maze, start_pos=(1, 1), max_health=100):
        super().__init__()

        self.maze = maze.copy()
        self.start_pos = start_pos
        self.player_pos = list(start_pos)
        self.has_key = False
        self.health = max_health
        self.max_health = max_health
        self.episode_log = []

        self.height, self.width = maze.shape
        self.observation_space = spaces.Dict({
            "view": spaces.Box(low=0, high=7, shape=self.maze.shape, dtype=np.int8),
            "position": spaces.Box(low=0, high=max(self.height, self.width), shape=(2,), dtype=np.int32),
            "has_key": spaces.Discrete(2),
            "health": spaces.Box(low=0, high=max_health, shape=(), dtype=np.int32),
        })

        self.action_space = spaces.Discrete(4)  # 0:UP, 1:DOWN, 2:LEFT, 3:RIGHT

    def reset(self, seed=None, options=None):
        self.player_pos = list(self.start_pos)
        self.has_key = False
        self.health = self.max_health
        self.visible_map = np.full_like(self.maze, fill_value=-1, dtype=np.int8)
        self._update_visibility()
        return self._get_obs(), {}

    def _update_visibility(self):
        x, y = self.player_pos
        for dx in range(-1, 2):
            for dy in range(-1, 2):
                nx, ny = x + dx, y + dy
                if 0 <= nx < self.height and 0 <= ny < self.width:
                    self.visible_map[nx, ny] = self.maze[nx, ny]


    def step(self, action):
        dx, dy = 0, 0
        if action == 0: dx, dy = -1, 0  # UP
        elif action == 1: dx, dy = 1, 0  # DOWN
        elif action == 2: dx, dy = 0, -1  # LEFT
        elif action == 3: dx, dy = 0, 1  # RIGHT

        new_x = self.player_pos[0] + dx
        new_y = self.player_pos[1] + dy

        reward = -0.1
        terminated = False

        if 0 <= new_x < self.height and 0 <= new_y < self.width:
            tile = self.maze[new_x, new_y]
            if tile != 1:  # не стена
                self.player_pos = [new_x, new_y]

                if tile == 2:  # ключ
                    self.has_key = True
                    self.maze[new_x, new_y] = 0
                    reward += 1

                elif tile == 3:  # дверь
                    if self.has_key:
                        pass  # можно пройти
                    else:
                        reward -= 1  # ударился об дверь

                elif tile == 4:  # ловушка
                    self.health -= 50
                    reward -= 5
                    if self.health <= 0:
                        terminated = True
                        reward -= 100

                elif tile == 5:  # костёр
                    self.health = min(self.max_health, self.health + 50)

                elif tile == 7:  # выход
                    if self.has_key:
                        reward += 10
                        terminated = True
                    else:
                        reward -= 1  # нужен ключ
                        
        self._update_visibility()

        obs = self._get_obs()
        self.episode_log.append([
            len(self.episode_log), *self.player_pos, action, tile, reward, self.health, int(self.has_key)
        ])
        return obs, float(reward), bool(terminated), False, {}


    def _get_obs(self):
        return {
            "view": self.visible_map.copy(),   # весь накопленный вид (вся карта)
            "position": np.array(self.player_pos, dtype=np.int32),
            "has_key": int(self.has_key),
            "health": self.health
        }


    def render(self):
        render_maze = self.maze.copy()
        x, y = self.player_pos
        render_maze[x, y] = 9  # агент
        symbols = {
            0: ' ', 1: '█', 2: 'K', 3: 'D',
            4: 'T', 5: 'C', 7: 'E', 9: 'A'
        }
        # print('\n'.join(''.join(symbols.get(cell, '?') for cell in row) for row in render_maze))
        # print(f"Pos: {self.player_pos}  HP: {self.health}  Key: {self.has_key}")

# %%
class FlattenObservationWrapper(ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        view_shape = env.observation_space.spaces["view"].shape
        self.observation_space = Box(
            low=0,
            high=1,
            shape=(view_shape[0] * view_shape[1] + 2 + 2,),  # view + has_key + health + position(2)
            dtype=np.float32,
        )

    def observation(self, obs):
        view_flat = (obs["view"].flatten().astype(np.float32) + 1) / 8.0  # нормализация сдвигом
        has_key = np.array([obs["has_key"]], dtype=np.float32)
        health = np.array([obs["health"] / self.env.max_health], dtype=np.float32)
        position = obs.get("position")
        if position is not None:
            position = position.astype(np.float32) / max(self.env.height, self.env.width)
            return np.concatenate([view_flat, has_key, health, position])
        else:
            return np.concatenate([view_flat, has_key, health])

# %%
# 1. Сгенерируем лабиринт
maze_id = str(uuid.uuid4())
maze_filename = f"maze_{maze_id}.csv"

maze = generate_maze(50, 50)


# 2. Обернём среду
env = MazeEnv(maze, start_pos=(1, 1))
env = FlattenObservationWrapper(env)

# 3. Проверим, что всё ок
check_env(env, warn=True)

# 4. Обучаем PPO
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./ppo_maze_tensorboard", n_steps=128)

# 5. Запуск обучения
model.learn(total_timesteps=10_000, progress_bar=True)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo_maze_tensorboard/PPO_3
# Output()
# /home/saatarko/anaconda3/envs/myenv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ----------------------------
# | time/              |     |
# |    fps             | 272 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 214           |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00014753174 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.0843       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.462         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 1.52          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 384          |
# | train/                  |              |
# |    approx_kl            | 0.0016909912 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.038       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0691       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 0.607        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0021719872 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00037     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.041        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 0.483        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 0.008172236 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0437     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0177      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 0.273       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.013749925 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0474      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 0.209       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 7            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 896          |
# | train/                  |              |
# |    approx_kl            | 0.0060067847 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000587    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0243       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 0.127        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.016966598 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00413    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.0918      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 9            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0015185447 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.00368     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00832      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -4.88e-05    |
# |    value_loss           | 0.0562       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 10          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.005052746 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.0248     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 0.0409      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 11           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1408         |
# | train/                  |              |
# |    approx_kl            | 0.0031993156 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | -0.000532    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00221     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000272    |
# |    value_loss           | 0.0244       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 12          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.001858817 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.0095     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0028      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0003     |
# |    value_loss           | 0.017       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 13          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1664        |
# | train/                  |             |
# |    approx_kl            | 0.005008524 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.00424     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00317    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 14          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.003687217 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00567     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 0.00675     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 15          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.013990689 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.00719    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00787    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 0.00537     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 16          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.010095123 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.00207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 17          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2176        |
# | train/                  |             |
# |    approx_kl            | 0.001380913 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.0156     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00532     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 4.06e-05    |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 18          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.016650006 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.00146     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 19          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.009133777 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0737      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00416     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 0.000941    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 20          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007421651 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.0282     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00375    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 0.000605    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 21          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2688        |
# | train/                  |             |
# |    approx_kl            | 0.026759285 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.0157     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.000462    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 22          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.011352754 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.00281     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0203      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 0.000238    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 351        |
# |    iterations           | 23         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 2944       |
# | train/                  |            |
# |    approx_kl            | 0.02015492 |
# |    clip_fraction        | 0.0961     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.169      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0307    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0122    |
# |    value_loss           | 0.000189   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 24          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.019293403 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.0104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0248     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.000125    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 25          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.020414256 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 8.89e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 26          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.025013171 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | -0.315      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00739    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 6.25e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 27         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 3456       |
# | train/                  |            |
# |    approx_kl            | 0.02098788 |
# |    clip_fraction        | 0.0867     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.765     |
# |    explained_variance   | -0.0507    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0102    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 4.44e-05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 28           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0033460665 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.0262       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 3.03e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 29           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3712         |
# | train/                  |              |
# |    approx_kl            | 0.0058632195 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.657       |
# |    explained_variance   | -0.059       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00854     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0078      |
# |    value_loss           | 2.22e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 30           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0062125246 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 1.44e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 31           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 3968         |
# | train/                  |              |
# |    approx_kl            | 0.0032725274 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | -2.21        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00579     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 1.49e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 32          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007757312 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0304     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 8.99e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 33           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 0.0028212825 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00211      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 7.77e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 34          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.006435335 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | -0.00213    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00779    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 9.87e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 35          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4480        |
# | train/                  |             |
# |    approx_kl            | 0.017279062 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | -0.0151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00955    |
# |    value_loss           | 8.47e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 36          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.009229679 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | -0.315      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 6.64e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 37           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4736         |
# | train/                  |              |
# |    approx_kl            | 0.0048576198 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.0454       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00569     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00728     |
# |    value_loss           | 5.07e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 38           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0040412447 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.639       |
# |    explained_variance   | 0.00166      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00216     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 3.95e-06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 361        |
# |    iterations           | 39         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 4992       |
# | train/                  |            |
# |    approx_kl            | 0.01000388 |
# |    clip_fraction        | 0.0602     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.621     |
# |    explained_variance   | -0.043     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0127    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00262   |
# |    value_loss           | 2.99e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 40          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.004172493 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | -0.115      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 2.35e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 41           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 5248         |
# | train/                  |              |
# |    approx_kl            | 0.0016456028 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.0135       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00676     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 2e-06        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 42          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.009302495 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.0156      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.58e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 43          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 5504        |
# | train/                  |             |
# |    approx_kl            | 0.002344978 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | -0.141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00447    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 1.28e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 44           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0012996476 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | -0.168       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00699     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 1.07e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 45          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 0.012164054 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 7.57e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 46          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.011638831 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | -0.00982    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000638   |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 6.65e-07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 358           |
# |    iterations           | 47            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 6016          |
# | train/                  |               |
# |    approx_kl            | 0.00016138749 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.672        |
# |    explained_variance   | -3.46         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00179       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | 0.000134      |
# |    value_loss           | 5.73e-07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 48          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007430567 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | -0.157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 4.42e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 49          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6272        |
# | train/                  |             |
# |    approx_kl            | 0.010552779 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | -4.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00862    |
# |    value_loss           | 4.34e-07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 357           |
# |    iterations           | 50            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 6400          |
# | train/                  |               |
# |    approx_kl            | 0.00027777487 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.431        |
# |    explained_variance   | -0.0973       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000403      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -8.56e-05     |
# |    value_loss           | 2.9e-07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 359           |
# |    iterations           | 51            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 6528          |
# | train/                  |               |
# |    approx_kl            | 7.8857876e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.433        |
# |    explained_variance   | 7.57e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00104      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 8.24e-05      |
# |    value_loss           | 2.28e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 52           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0011941972 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | -1.07        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00132      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 2.3e-07      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 356           |
# |    iterations           | 53            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 6784          |
# | train/                  |               |
# |    approx_kl            | 0.00054084696 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.366        |
# |    explained_variance   | 3.58e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00385      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000333     |
# |    value_loss           | 1.38e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 54           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0011298396 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | -0.566       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0155      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 1.22e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 55           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 7040         |
# | train/                  |              |
# |    approx_kl            | 6.429199e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | 6.56e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00137      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | 0.000181     |
# |    value_loss           | 8.21e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 56           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0096866265 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 5.09e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00877     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00768     |
# |    value_loss           | 6.36e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 57           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 7296         |
# | train/                  |              |
# |    approx_kl            | 0.0022958647 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | -0.198       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0111      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 9.03e-08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 353           |
# |    iterations           | 58            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 7424          |
# | train/                  |               |
# |    approx_kl            | 0.00012866128 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.238        |
# |    explained_variance   | -2.07         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00313      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000411     |
# |    value_loss           | 5.39e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 352           |
# |    iterations           | 59            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 7552          |
# | train/                  |               |
# |    approx_kl            | 0.00038376777 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.244        |
# |    explained_variance   | 2.75e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00232      |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000553     |
# |    value_loss           | 2.74e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 353           |
# |    iterations           | 60            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 0.00031636236 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.228        |
# |    explained_variance   | 4.29e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00489      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000583     |
# |    value_loss           | 2.05e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 61            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 7808          |
# | train/                  |               |
# |    approx_kl            | 0.00051742373 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.241        |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000785      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.000259     |
# |    value_loss           | 1.4e-08       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 345           |
# |    iterations           | 62            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 7936          |
# | train/                  |               |
# |    approx_kl            | 0.00026714895 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.221        |
# |    explained_variance   | -2.76         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0036       |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -0.00109      |
# |    value_loss           | 4.77e-08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 63           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8064         |
# | train/                  |              |
# |    approx_kl            | 0.0020153155 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 1.03e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00652     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 7.51e-09     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 344           |
# |    iterations           | 64            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00021751411 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.172        |
# |    explained_variance   | 9.79e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00191      |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -0.00058      |
# |    value_loss           | 6.28e-09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 343           |
# |    iterations           | 65            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 8320          |
# | train/                  |               |
# |    approx_kl            | 0.00023558736 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.152        |
# |    explained_variance   | 0.000821      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0022       |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -0.000391     |
# |    value_loss           | 4.03e-09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 341           |
# |    iterations           | 66            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 8448          |
# | train/                  |               |
# |    approx_kl            | 0.00039615575 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.142        |
# |    explained_variance   | 0.217         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.011        |
# |    n_updates            | 650           |
# |    policy_gradient_loss | -0.00268      |
# |    value_loss           | 6.14e-08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 67           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8576         |
# | train/                  |              |
# |    approx_kl            | 0.0015462544 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.165       |
# |    explained_variance   | 3.96e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00543      |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 3e-09        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 68           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0002421597 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.175       |
# |    explained_variance   | 0.000451     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00663     |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.000258    |
# |    value_loss           | 2.18e-09     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 69            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 8832          |
# | train/                  |               |
# |    approx_kl            | 0.00015689945 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.19         |
# |    explained_variance   | 0.000294      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00112      |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -9.96e-05     |
# |    value_loss           | 1.53e-09      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 70           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0006314418 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 3.05e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00444     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 9.81e-10     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 71           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 9088         |
# | train/                  |              |
# |    approx_kl            | 0.0033881185 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0.0109       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 5.51e-10     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 72            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00018406752 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.197        |
# |    explained_variance   | 0.000107      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -8.96e-05     |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000455     |
# |    value_loss           | 5.03e-10      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 73           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 9344         |
# | train/                  |              |
# |    approx_kl            | 0.0011600195 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0.00469      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00606     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 2.44e-10     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 341           |
# |    iterations           | 74            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 9472          |
# | train/                  |               |
# |    approx_kl            | 0.00022613024 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.152        |
# |    explained_variance   | 0.00499       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.85e-08      |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.00107      |
# |    value_loss           | 2.42e-10      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 75           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0012061731 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.167       |
# |    explained_variance   | 0.00469      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00252     |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 2.23e-10     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 76          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 4.88339e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.186      |
# |    explained_variance   | 0.00188     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000246   |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 2.46e-05    |
# |    value_loss           | 6.69e-11    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 77            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 9856          |
# | train/                  |               |
# |    approx_kl            | 0.00035405718 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.183        |
# |    explained_variance   | -6.93         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0035       |
# |    n_updates            | 760           |
# |    policy_gradient_loss | -0.00131      |
# |    value_loss           | 3.39e-08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 78           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0013852622 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.183       |
# |    explained_variance   | 0.0521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0018      |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 6.28e-11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 79           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 10112        |
# | train/                  |              |
# |    approx_kl            | 0.0029931972 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.136       |
# |    explained_variance   | 0.0521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00358     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 6.78e-11     |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
obs, _ = env.reset()
done = False
step_count = 0
log_filename = f"episode_log_{maze_id}.csv"
max_steps = maze.shape[0] * maze.shape[1]

while not done and step_count < max_steps:
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()
    step_count += 1

if not done:
    print(f"Лабиринт {maze_id} НЕ ПРОЙДЕН")
    env.unwrapped.episode_log.append([
        step_count, *env.unwrapped.player_pos, -1, -1, -999, env.unwrapped.health, int(env.unwrapped.has_key)
    ])

# 6. Сохраняем результаты с id
save_maze(maze, maze_filename)
save_episode_log(env.unwrapped.episode_log, log_filename)
# Out:
# Лабиринт edccaf26-74a7-4365-98c6-741e83f972d3 НЕ ПРОЙДЕН
